# %%
import random
import datetime
import time
import matplotlib.dates

t_sleep=1

print('enter any no:')
seedvalue=int(input())
delta=100
#for x in range(n):

   # print(str(datetime.datetime.now()))
    #print(random.uniform(7000,16000))
    #time.sleep(t_sleep)
x_values=[] 
y_values=[]
for x in range(50):
    x_values.append(str(datetime.datetime.now()))
    print(str(datetime.datetime.now()))
    currentvalue=  random.uniform(seedvalue-delta,seedvalue+delta)
    finalvalue=random.uniform(currentvalue-delta,currentvalue+delta)
    format_float = "{:.2f}".format( finalvalue)
    y_values.append(format_float)
    print(format_float)
dates = matplotlib.dates.date2num(x_values)    
plt.plot_date(dates, y_values)
# Out:
# enter any no:
# 7000
# 2022-06-10 07:57:29.364965
# 7026.45
# 2022-06-10 07:57:29.365965
# 6997.47
# 2022-06-10 07:57:29.365965
# 7051.80
# 2022-06-10 07:57:29.366964
# 7018.89
# 2022-06-10 07:57:29.367961
# 7015.69
# 2022-06-10 07:57:29.368963
# 6928.75
# 2022-06-10 07:57:29.368963
# 7020.40
# 2022-06-10 07:57:29.368963
# 7035.53
# 2022-06-10 07:57:29.368963
# 7052.48
# 2022-06-10 07:57:29.368963
# 6958.17
# 2022-06-10 07:57:29.370960
# 7080.03
# 2022-06-10 07:57:29.370960
# 7069.37
# 2022-06-10 07:57:29.370960
# 7092.14
# 2022-06-10 07:57:29.370960
# 7047.98
# 2022-06-10 07:57:29.370960
# 7108.39
# 2022-06-10 07:57:29.370960
# 7112.79
# 2022-06-10 07:57:29.370960
# 7057.23
# 2022-06-10 07:57:29.370960
# 7114.09
# 2022-06-10 07:57:29.371959
# 6987.69
# 2022-06-10 07:57:29.371959
# 7139.03
# 2022-06-10 07:57:29.371959
# 7142.05
# 2022-06-10 07:57:29.371959
# 7004.57
# 2022-06-10 07:57:29.371959
# 6909.96
# 2022-06-10 07:57:29.371959
# 6900.34
# 2022-06-10 07:57:29.371959
# 6961.39
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.xlabel("datetime.datetime.now()")
plt.ylabel("format_float")
plt.title("random no vs datetime")
plt.plot(x_values,y_values)
plt.show()

# %%
import random
j=random.randrange(900)
i=1
li={}
for x in range(7000,16001,j):
    if x+j >16000:
        print(x,"-","16000","(Gap :",16000-x,")","Zone",i)
        li[i]= 16000
        break
    else:
       
        print(x ,"-", x+j,"(Gap :",j,")","Zone",i)
        li[i]= x+j
        i=i+1
        j=random.randrange(900)
# Out:
# 7000 - 7382 (Gap : 382 ) Zone 1
# 7382 - 7566 (Gap : 184 ) Zone 2
# 7764 - 7942 (Gap : 178 ) Zone 3
# 8146 - 8637 (Gap : 491 ) Zone 4
# 8528 - 9003 (Gap : 475 ) Zone 5
# 8910 - 9795 (Gap : 885 ) Zone 6
# 9292 - 9921 (Gap : 629 ) Zone 7
# 9674 - 10528 (Gap : 854 ) Zone 8
# 10056 - 10544 (Gap : 488 ) Zone 9
# 10438 - 11006 (Gap : 568 ) Zone 10
# 10820 - 10964 (Gap : 144 ) Zone 11
# 11202 - 11913 (Gap : 711 ) Zone 12
# 11584 - 12199 (Gap : 615 ) Zone 13
# 11966 - 12741 (Gap : 775 ) Zone 14
# 12348 - 12425 (Gap : 77 ) Zone 15
# 12730 - 13544 (Gap : 814 ) Zone 16
# 13112 - 13539 (Gap : 427 ) Zone 17
# 13494 - 14193 (Gap : 699 ) Zone 18
# 13876 - 14318 (Gap : 442 ) Zone 19
# 14258 - 14440 (Gap : 182 ) Zone 20
# 14640 - 15274 (Gap : 634 ) Zone 21
# 15022 - 15602 (Gap : 580 ) Zone 22
# 15404 - 15560 (Gap : 156 ) Zone 23
# 15786 - 15940 (Gap : 154 ) Zone 24

# %%
import random

i=1
li={}
x=7000
while x<16000:
    if x+j >16000:
        print(x,"-","16000","(Gap :",16000-x,")","Zone",i)
        li[i]= 16000
        break
    else:
        j=random.randrange(900)
        print(x ,"-", x+j,"(Gap :",j,")","Zone",i)
        li[i]= x+j
        x=x+j
        i=i+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9de0dfeaf878> in <module>
#       5 x=7000
#       6 while x<16000:
# ----> 7     if x+j >16000:
#       8         print(x,"-","16000","(Gap :",16000-x,")","Zone",i)
#       9         li[i]= 16000
#
# NameError: name 'j' is not defined

# %%
li
# Out:
# {1: 7115,
#  2: 7584,
#  3: 8374,
#  4: 8794,
#  5: 9097,
#  6: 9680,
#  7: 9937,
#  8: 10059,
#  9: 10633,
#  10: 10747,
#  11: 11641,
#  12: 12024,
#  13: 12236,
#  14: 12855,
#  15: 12965,
#  16: 13096,
#  17: 13602,
#  18: 14157,
#  19: 14837,
#  20: 14854,
#  21: 15329,
#  22: 15791,
#  23: 16000}

# %%
n=int(input())
for x in li:
    if n> 16000 or n<7000:
        print("Give correct input") 
        break
    elif li[x]>=n :
        print(" input no is present in Zone",x)
        break
# Out:
# 12000
#  input no is present in Zone 12

# %%
import random

j=random.randrange(900)
i=1
li={}
x=7000
while x<16000:
    if x+j >16000:
        print(x,"-","16000","(Gap :",16000-x,")","Zone",i)
        li[i]= 16000
        break
    else:
        j=random.randrange(900)
        print(x ,"-", x+j,"(Gap :",j,")","Zone",i)
        li[x]= x+j
        x=x+j
        i=i+1
# Out:
# 7000 - 7259 (Gap : 259 ) Zone 1
# 7259 - 8005 (Gap : 746 ) Zone 2
# 8005 - 8511 (Gap : 506 ) Zone 3
# 8511 - 9196 (Gap : 685 ) Zone 4
# 9196 - 9928 (Gap : 732 ) Zone 5
# 9928 - 10198 (Gap : 270 ) Zone 6
# 10198 - 10317 (Gap : 119 ) Zone 7
# 10317 - 10632 (Gap : 315 ) Zone 8
# 10632 - 10662 (Gap : 30 ) Zone 9
# 10662 - 10853 (Gap : 191 ) Zone 10
# 10853 - 11368 (Gap : 515 ) Zone 11
# 11368 - 11578 (Gap : 210 ) Zone 12
# 11578 - 11635 (Gap : 57 ) Zone 13
# 11635 - 12333 (Gap : 698 ) Zone 14
# 12333 - 12714 (Gap : 381 ) Zone 15
# 12714 - 13251 (Gap : 537 ) Zone 16
# 13251 - 14011 (Gap : 760 ) Zone 17
# 14011 - 14090 (Gap : 79 ) Zone 18
# 14090 - 14971 (Gap : 881 ) Zone 19
# 14971 - 15445 (Gap : 474 ) Zone 20
# 15445 - 15972 (Gap : 527 ) Zone 21
# 15972 - 16000 (Gap : 28 ) Zone 22

# %%
li
# Out:
# {7000: 7259,
#  7259: 8005,
#  8005: 8511,
#  8511: 9196,
#  9196: 9928,
#  9928: 10198,
#  10198: 10317,
#  10317: 10632,
#  10632: 10662,
#  10662: 10853,
#  10853: 11368,
#  11368: 11578,
#  11578: 11635,
#  11635: 12333,
#  12333: 12714,
#  12714: 13251,
#  13251: 14011,
#  14011: 14090,
#  14090: 14971,
#  14971: 15445,
#  15445: 15972,
#  22: 16000}

# %%
k=1
#print("enter no :")
n=random.randrange(7000,16000)
print(n)
for x in li:
    if n> 16000 or n<7000:
        print("Give correct input") 
        break
    elif n>=x and n<li[x]:
        print("  no is present in Zone",k)
        break
    else:
        k=k+1
# Out:
# 11279
#   no is present in Zone 11

# %%
#detecting patterns by open cv(yolo)
